# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/Rain_%26_Agriculture_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('rain-agriculture.csv')
df.head(11)
# Out:
#         State Name  Year  Dist Code  State Code  RICE AREA (1000 ha)  \
# 0   andhra pradesh  1966       49.0         1.0           218.272727
# 1   andhra pradesh  1967       49.0         1.0           220.181818
# 2   andhra pradesh  1968       49.0         1.0           203.527273
# 3   andhra pradesh  1969       49.0         1.0           227.118182
# 4   andhra pradesh  1970       49.0         1.0           225.745455
# 5   andhra pradesh  1971       49.0         1.0           215.272727
# 6   andhra pradesh  1972       49.0         1.0           206.181818
# 7   andhra pradesh  1973       49.0         1.0           212.118182
# 8   andhra pradesh  1974       49.0         1.0           227.154545
# 9   andhra pradesh  1975       49.0         1.0           240.900000
# 10  andhra pradesh  1976       49.0         1.0           217.400000
#
#     RICE PRODUCTION (1000 tons)  RICE YIELD (Kg per ha)  WHEAT AREA (1000 ha)  \
# ...

# %%
df.tail(11)
# Out:
#       State Name  Year   Dist Code  State Code  RICE AREA (1000 ha)  \
# 925  west bengal  2009  810.533333   13.000000           375.340000
# 926  west bengal  2010  810.533333   13.000000           329.610000
# 927  west bengal  2011  810.533333   13.000000           362.246667
# 928  west bengal  2012  810.533333   13.000000           362.956000
# 929  west bengal  2013  810.533333   13.000000           367.580000
# 930  west bengal  2014  810.533333   13.000000           368.434667
# 931  west bengal  2015  810.533333   13.000000           368.264000
# 932  west bengal  2016  810.533333   13.000000           347.467333
# 933  west bengal  2017  810.533333   13.000000           353.846000
# 934    jharkhand  1995  335.030456   10.491329           164.332063
# 935    jharkhand  1996  335.030456   10.491329           164.332063
#
#      RICE PRODUCTION (1000 tons)  RICE YIELD (Kg per ha)  \
# 925                   956.040000             2471.027333
# ...

# %%
df.shape
# Out:
# (936, 85)

# %%
df.columns
# Out:
# Index(['State Name', 'Year', 'Dist Code', 'State Code', 'RICE AREA (1000 ha)',
#        'RICE PRODUCTION (1000 tons)', 'RICE YIELD (Kg per ha)',
#        'WHEAT AREA (1000 ha)', 'WHEAT PRODUCTION (1000 tons)',
#        'WHEAT YIELD (Kg per ha)', 'KHARIF SORGHUM AREA (1000 ha)',
#        'KHARIF SORGHUM PRODUCTION (1000 tons)',
#        'KHARIF SORGHUM YIELD (Kg per ha)', 'RABI SORGHUM AREA (1000 ha)',
#        'RABI SORGHUM PRODUCTION (1000 tons)', 'RABI SORGHUM YIELD (Kg per ha)',
#        'SORGHUM AREA (1000 ha)', 'SORGHUM PRODUCTION (1000 tons)',
#        'SORGHUM YIELD (Kg per ha)', 'PEARL MILLET AREA (1000 ha)',
#        'PEARL MILLET PRODUCTION (1000 tons)', 'PEARL MILLET YIELD (Kg per ha)',
#        'MAIZE AREA (1000 ha)', 'MAIZE PRODUCTION (1000 tons)',
#        'MAIZE YIELD (Kg per ha)', 'FINGER MILLET AREA (1000 ha)',
#        'FINGER MILLET PRODUCTION (1000 tons)',
#        'FINGER MILLET YIELD (Kg per ha)', 'BARLEY AREA (1000 ha)',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 936 entries, 0 to 935
# Data columns (total 85 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   State Name                                   936 non-null    object
#  1   Year                                         936 non-null    int64
#  2   Dist Code                                    936 non-null    float64
#  3   State Code                                   936 non-null    float64
#  4   RICE AREA (1000 ha)                          936 non-null    float64
#  5   RICE PRODUCTION (1000 tons)                  936 non-null    float64
#  6   RICE YIELD (Kg per ha)                       936 non-null    float64
#  7   WHEAT AREA (1000 ha)                         936 non-null    float64
#  8   WHEAT PRODUCTION (1000 tons)                 936 non-null    float64
# ...

# %%
df.describe(include = 'all')
# Out:
#             State Name         Year   Dist Code  State Code  \
# count              936   936.000000  936.000000  936.000000
# unique              18          NaN         NaN         NaN
# top     andhra pradesh          NaN         NaN         NaN
# freq                52          NaN         NaN         NaN
# mean               NaN  1991.500000  368.783840    9.768144
# std                NaN    15.016355  313.408031    5.541112
# min                NaN  1966.000000   25.000000    1.000000
# 25%                NaN  1978.750000  107.500000    5.000000
# 50%                NaN  1991.500000  197.395963    9.500000
# 75%                NaN  2004.250000  656.200000   15.000000
# max                NaN  2017.000000  914.166667   19.000000
#
#         RICE AREA (1000 ha)  RICE PRODUCTION (1000 tons)  \
# count            936.000000                   936.000000
# unique                  NaN                          NaN
# top                     NaN                          NaN
# ...

# %%
df.isnull().sum()
# Out:
# State Name             0
# Year                   0
# Dist Code              0
# State Code             0
# RICE AREA (1000 ha)    0
#                       ..
# YEAR                   0
# JUN                    0
# JUL                    0
# AUG                    0
# SEP                    0
# Length: 85, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Handling Outliers

# %%
Q1 = df['SUNFLOWER PRODUCTION (1000 tons)'].quantile(0.25)
Q3 = df['SUNFLOWER PRODUCTION (1000 tons)'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_outliers = df[(df['SUNFLOWER PRODUCTION (1000 tons)'] >= lower_bound) & (df['SUNFLOWER PRODUCTION (1000 tons)'] <= upper_bound)].copy()

print('Before removing outliers:', len(df))
print('After removing outliers:',len(df_outliers))
# Out:
# Before removing outliers: 936
# After removing outliers: 752

# %%
# Creating a figure with two subplots (1 row, 2 columns)
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

sns.boxplot(data=df, y='SUNFLOWER PRODUCTION (1000 tons)', ax=axes[0])
axes[0].set_title('Box plot Before Outlier Removal')
axes[0].set_ylabel('SUNFLOWER PRODUCTION (1000 tons)')

sns.boxplot(data=df_outliers, y='SUNFLOWER PRODUCTION (1000 tons)', ax=axes[1])
axes[1].set_title('Box plot After Outlier Removal')
axes[1].set_ylabel('SUNFLOWER PRODUCTION (1000 tons)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Univariate Analysis

# %%
# Get a list of numerical columns
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through numerical columns and create histograms
for col in numerical_cols:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=col, kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# Get a list of categorical columns
categorical_cols = df.select_dtypes(include='object').columns.tolist()

# Iterate through categorical columns and create countplots
for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, x=col)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right') # Rotate labels for better readability
    plt.tight_layout() # Adjust layout to prevent labels overlapping
    plt.show()

# You can also use value_counts for a quick look at categorical data distribution
for col in categorical_cols:
    print(f"Value counts for {col}:\n{df[col].value_counts()}\n")
# Out:
# Value counts for State Name:
# State Name
# andhra pradesh      52
# assam               52
# bihar               52
# gujarat             52
# haryana             52
# himachal pradesh    52
# jharkhand           52
# karnataka           52
# kerala              52
# madhya pradesh      52
# maharashtra         52
# orissa              52
# punjab              52
# rajasthan           52
# tamil nadu          52
# uttar pradesh       52
# uttarakhand         52
# west bengal         52
# Name: count, dtype: int64
#
# Value counts for subdivision:
# subdivision
# andhra pradesh      52
# assam               52
# bihar               52
# gujarat             52
# haryana             52
# himachal pradesh    52
# jharkhand           52
# karnataka           52
# kerala              52
# madhya pradesh      52
# maharashtra         52
# orissa              52
# punjab              52
# rajasthan           52
# tamil nadu          52
# uttar pradesh       52
# uttarakhand         52
# ...

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# # To BIG TO UPLOAD ON GITHUB:

# %%
'''# Numerical-Numerical relationships (Scatter plots)
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through pairs of numerical columns and create scatter plots
for i in range(len(numerical_cols)):
    for j in range(i + 1, len(numerical_cols)):
        col1 = numerical_cols[i]
        col2 = numerical_cols[j]
        plt.figure(figsize=(10, 6))
        sns.scatterplot(data=df, x=col1, y=col2)
        plt.title(f'Scatter plot of {col1} vs {col2}')
        plt.xlabel(col1)
        plt.ylabel(col2)
        plt.show()

# Categorical-Numerical relationships (Box plots)
categorical_cols = df.select_dtypes(include='object').columns.tolist()
numerical_cols = df.select_dtypes(include=np.number).columns.tolist() # Re-get numerical columns in case df was modified

# Iterate through categorical and numerical columns and create box plots
for cat_col in categorical_cols:
    for num_col in numerical_cols:
        plt.figure(figsize=(10, 6))
        sns.boxplot(data=df, x=cat_col, y=num_col)
        plt.title(f'Box plot of {num_col} by {cat_col}')
        plt.xlabel(cat_col)
        plt.ylabel(num_col)
        plt.xticks(rotation=45, ha='right')
        plt.tight_layout()
        plt.show()'''
# Out:
# "# Numerical-Numerical relationships (Scatter plots)\nnumerical_cols = df.select_dtypes(include=np.number).columns.tolist()\n\n# Iterate through pairs of numerical columns and create scatter plots\nfor i in range(len(numerical_cols)):\n    for j in range(i + 1, len(numerical_cols)):\n        col1 = numerical_cols[i]\n        col2 = numerical_cols[j]\n        plt.figure(figsize=(10, 6))\n        sns.scatterplot(data=df, x=col1, y=col2)\n        plt.title(f'Scatter plot of {col1} vs {col2}')\n        plt.xlabel(col1)\n        plt.ylabel(col2)\n        plt.show()\n\n# Categorical-Numerical relationships (Box plots)\ncategorical_cols = df.select_dtypes(include='object').columns.tolist()\nnumerical_cols = df.select_dtypes(include=np.number).columns.tolist() # Re-get numerical columns in case df was modified\n\n# Iterate through categorical and numerical columns and create box plots\nfor cat_col in categorical_cols:\n    for num_col in numerical_cols:\n        plt.figure(figsize=(10, 6))\n
# ...

# %% [markdown]
# # TO BIG TO DISPLAY ON GITHUB

# %%
'''sns.pairplot(df.select_dtypes(include=np.number))
plt.suptitle('Pairplot of Numerical Features', y=1.02)
plt.show()'''
# Out:
# "sns.pairplot(df.select_dtypes(include=np.number))\nplt.suptitle('Pairplot of Numerical Features', y=1.02)\nplt.show()"

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(df.corr(numeric_only = True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix", fontsize=14)
plt.show()

# %% [markdown]
# # Thank you
