# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/Pet_Adoption_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('pet_adoption_center.csv')
df.head(11)
# Out:
#    pet_id pet_name  species               breed  age_years  gender    color  \
# 0   P0001   Sandra      Dog   Yorkshire Terrier          2  Female    White
# 1   P0002    Brian      Cat           Tonkinese          1  Female   Golden
# 2   P0003  Timothy     Bird       Amazon Parrot          4    Male  Spotted
# 3   P0004     Karl      Dog     German Shepherd          1  Female    White
# 4   P0005    Sarah   Rabbit               Dutch          1  Female  Spotted
# 5   P0006     Dawn      Dog  Labrador Retriever         15    Male  Spotted
# 6   P0007     Chad      Dog      Siberian Husky         15  Female    Mixed
# 7   P0008   Jeanne  Hamster    Campbell's Dwarf          4  Female  Spotted
# 8   P0009     Ryan      Cat          Abyssinian         11  Female    Mixed
# 9   P0010  Richard      Dog      French Bulldog          1    Male    Brown
# 10  P0011  Charles  Hamster             Chinese          7    Male     Grey
#
# ...

# %%
df.tail(11)
# Out:
#     pet_id pet_name  species               breed  age_years  gender    color  \
# 189  P0190   Ashley     Bird            Lovebird         13  Female    Brown
# 190  P0191   Sharon   Rabbit      English Angora          6  Female     Grey
# 191  P0192   Sandra   Rabbit            Lionhead          7  Female    White
# 192  P0193  Cynthia  Hamster    European Hamster          2    Male    Black
# 193  P0194    David     Bird           Cockatiel          4    Male    White
# 194  P0195  Natalie   Rabbit            Lionhead         14    Male    Brown
# 195  P0196  Melissa  Hamster             Chinese          8    Male    White
# 196  P0197    Ricky      Dog  Labrador Retriever          4  Female   Golden
# 197  P0198    Carly   Rabbit       Flemish Giant          5    Male  Spotted
# 198  P0199      Don      Dog          Great Dane          1    Male    Mixed
# 199  P0200    Caleb     Bird              Canary          5    Male   Golden
#
# ...

# %%
df.shape
# Out:
# (200, 15)

# %%
df.columns
# Out:
# Index(['pet_id', 'pet_name', 'species', 'breed', 'age_years', 'gender',
#        'color', 'arrival_date', 'adopted', 'adoption_date', 'adopter_id',
#        'adopter_name', 'adopter_age', 'adopter_city', 'adopter_previous_pets'],
#       dtype='object')

# %%
df.dtypes
# Out:
# pet_id                   object
# pet_name                 object
# species                  object
# breed                    object
# age_years                 int64
# gender                   object
# color                    object
# arrival_date             object
# adopted                    bool
# adoption_date            object
# adopter_id               object
# adopter_name             object
# adopter_age               int64
# adopter_city             object
# adopter_previous_pets     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   pet_id                 200 non-null    object
#  1   pet_name               200 non-null    object
#  2   species                200 non-null    object
#  3   breed                  200 non-null    object
#  4   age_years              200 non-null    int64
#  5   gender                 200 non-null    object
#  6   color                  200 non-null    object
#  7   arrival_date           200 non-null    object
#  8   adopted                200 non-null    bool
#  9   adoption_date          200 non-null    object
#  10  adopter_id             118 non-null    object
#  11  adopter_name           118 non-null    object
#  12  adopter_age            200 non-null    int64
#  13  adopter_city           118 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# pet_id                    0
# pet_name                  0
# species                   0
# breed                     0
# age_years                 0
# gender                    0
# color                     0
# arrival_date              0
# adopted                   0
# adoption_date             0
# adopter_id               82
# adopter_name             82
# adopter_age               0
# adopter_city             82
# adopter_previous_pets     0
# dtype: int64

# %%
df.describe(include = 'all')
# Out:
#        pet_id pet_name species   breed   age_years  gender    color  \
# count     200      200     200     200  200.000000     200      200
# unique    200      137       5      58         NaN       2        7
# top     P0001  Richard     Cat  Syrian         NaN  Female  Spotted
# freq        1        6      45       8         NaN     107       37
# mean      NaN      NaN     NaN     NaN    7.545000     NaN      NaN
# std       NaN      NaN     NaN     NaN    4.512181     NaN      NaN
# min       NaN      NaN     NaN     NaN    1.000000     NaN      NaN
# 25%       NaN      NaN     NaN     NaN    4.000000     NaN      NaN
# 50%       NaN      NaN     NaN     NaN    7.000000     NaN      NaN
# 75%       NaN      NaN     NaN     NaN   12.000000     NaN      NaN
# max       NaN      NaN     NaN     NaN   15.000000     NaN      NaN
#
#        arrival_date adopted adoption_date adopter_id  adopter_name  \
# count           200     200           200        118           118
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Handling Outliers

# %%
Q1 = df['age_years'].quantile(0.25)
Q3 = df['age_years'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_outliers = df[(df['age_years'] >= lower_bound) & (df['age_years'] <= upper_bound)].copy()

print('Before removing outliers:', len(df))
print('After remvoing outliers:', len(df_outliers))
# Out:
# Before removing outliers: 200
# After remvoing outliers: 200

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

sns.boxplot(data=df, y='age_years', ax=axes[0])
axes[0].set_title('Box plot Before Outlier Removal')
axes[0].set_ylabel('age_years')

sns.boxplot(data=df_outliers, y='age_years', ax=axes[1])
axes[1].set_title('Box plot After Outlier Removal')
axes[1].set_ylabel('age_years')

plt.tight_layout()

plt.show()

# %% [markdown]
# # Univariate Analysis

# %%
# Getting a list of numerical columns
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through numerical columns and create histograms
for col in numerical_cols:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=col, kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# Getting a list of categorical columns
categorical_cols = df.select_dtypes(include='object').columns.tolist()

# Iterate through categorical columns and create countplots
for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, x=col)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# You can also use value_counts for a quick look at categorical data distribution
for col in categorical_cols:
    print(f"Value counts for {col}:\n{df[col].value_counts()}\n")
# Out:
# Value counts for pet_id:
# pet_id
# P0001    1
# P0002    1
# P0003    1
# P0004    1
# P0005    1
#         ..
# P0196    1
# P0197    1
# P0198    1
# P0199    1
# P0200    1
# Name: count, Length: 200, dtype: int64
#
# Value counts for pet_name:
# pet_name
# Richard    6
# Michael    5
# John       4
# David      4
# Heather    4
#           ..
# Natalie    1
# Ricky      1
# Carly      1
# Don        1
# Caleb      1
# Name: count, Length: 137, dtype: int64
#
# Value counts for species:
# species
# Cat        45
# Hamster    44
# Dog        43
# Bird       36
# Rabbit     32
# Name: count, dtype: int64
#
# Value counts for breed:
# breed
# Syrian                  8
# Lionhead                8
# Conure                  7
# Roborovski              7
# Korean                  7
# Dutch                   6
# Great Dane              6
# Macaw                   6
# Golden Retriever        6
# Devon Rex               6
# Maine Coon              5
# Boxer                   5
# ...

# %% [markdown]
# # Bivariate Analysis

# %%
# Numerical-Numerical relationships (Scatter plots)
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through pairs of numerical columns and create scatter plots
for i in range(len(numerical_cols)):
    for j in range(i + 1, len(numerical_cols)):
        col1 = numerical_cols[i]
        col2 = numerical_cols[j]
        plt.figure(figsize=(10, 6))
        sns.scatterplot(data=df, x=col1, y=col2)
        plt.title(f'Scatter plot of {col1} vs {col2}')
        plt.xlabel(col1)
        plt.ylabel(col2)
        plt.show()

# Categorical-Numerical relationships (Box plots)
categorical_cols = df.select_dtypes(include='object').columns.tolist()
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through categorical and numerical columns and create box plots
for cat_col in categorical_cols:
    for num_col in numerical_cols:
        plt.figure(figsize=(10, 6))
        sns.boxplot(data=df, x=cat_col, y=num_col)
        plt.title(f'Box plot of {num_col} by {cat_col}')
        plt.xlabel(cat_col)
        plt.ylabel(num_col)
        plt.xticks(rotation=45, ha='right')
        plt.tight_layout()
        plt.show()

# %%
sns.pairplot(df.select_dtypes(include=np.number))
plt.suptitle('Pairplot of Numerical Features', y=1.02)
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(df.corr(numeric_only = True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix", fontsize=14)
plt.show()

# %% [markdown]
# # Thank you
