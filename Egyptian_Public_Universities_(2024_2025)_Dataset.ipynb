# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/Egyptian_Public_Universities_(2024_2025)_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Egyptian Public University - (2024-2025)

# %% [markdown]
# # About the dataset

# %% [markdown]
# The dataset provides a comprehensive overview of Egyptian Public Universities for the academic year 2024-2025. Comprising 2139 entries and 13 columns, it details university names, faculties, departments, city locations, founding years, academic streams, and critical admission criteria such as minimum absolute scores and percentages.
#
# Initial data exploration revealed a clean dataset with no duplicate entries. A minor portion of Founded_Year_clean data (69 entries) was missing, which may need imputation if that column is used for deeper analysis, though it doesn't hinder current insights.
#
# Key observations from the analysis include the prominence of Cairo and Helwan Universities, along with Faculties of Medicine and Science, suggesting a strong focus on these institutions and fields within the public university system. Cairo is also the most frequently represented city. All institutions in this dataset are public.
#
# Admission requirements vary significantly across different academic streams, faculties, and college types. Science streams, for instance, generally demand higher minimum absolute scores and percentages compared to literary streams. The strong positive correlation (0.99) between 'Minimum Absolute Score' and 'Minimum Percentage (%)' confirms their direct relationship. The founding year of a university, ranging from 1908 to 2012, shows a weak correlation with admission scores, implying that age is not a strong determinant of academic rigor in terms of entry requirements.
#
# These insights are valuable for prospective students to understand university distribution, popular fields of study, and admission benchmarks across Egypt's public higher education landscape.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
# Installing Kaggle API
# !pip install -q kaggle

# Uploading kaggle.json
from google.colab import files
files.upload()

# Moving kaggle.json to ~/.kaggle/
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# Downloading the dataset using Kaggle API
# !kaggle datasets download -d shreyashpatil217/egyptian-public-universities-2024-2025

# Unziping the downloaded file
# !unzip egyptian-public-universities-2024-2025.zip
# Out:
#      <input type="file" id="files-4542b4ae-cb23-42a8-9a6e-db2a6091a524" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4542b4ae-cb23-42a8-9a6e-db2a6091a524">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Universities_Egypt.csv')
df.head(11)
# Out:
#           University_uni              Faculty               Department   City  \
# 0   ain shams university  Faculty of Medicine        Internal Medicine  Cairo
# 1   ain shams university  Faculty of Medicine        Internal Medicine  Cairo
# 2   ain shams university  Faculty of Medicine        Internal Medicine  Cairo
# 3   ain shams university  Faculty of Medicine                  Surgery  Cairo
# 4   ain shams university  Faculty of Medicine                  Surgery  Cairo
# 5   ain shams university  Faculty of Medicine                  Surgery  Cairo
# 6   ain shams university  Faculty of Medicine               Pediatrics  Cairo
# 7   ain shams university  Faculty of Medicine               Pediatrics  Cairo
# 8   ain shams university  Faculty of Medicine               Pediatrics  Cairo
# 9   ain shams university  Faculty of Medicine  Obstetrics & Gynecology  Cairo
# 10  ain shams university  Faculty of Medicine  Obstetrics & Gynecology  Cairo
#
# ...

# %%
df.tail(11)
# Out:
#           University_uni                  Faculty                 Department  \
# 2128  zagazig university   Faculty of Dar El-Ulum            Arabic Language
# 2129  zagazig university   Faculty of Dar El-Ulum             Quran Sciences
# 2130  zagazig university   Faculty of Dar El-Ulum             Quran Sciences
# 2131  zagazig university   Faculty of Dar El-Ulum                   Theology
# 2132  zagazig university   Faculty of Dar El-Ulum                   Theology
# 2133  zagazig university  Faculty of Kindergarten  Early Childhood Education
# 2134  zagazig university  Faculty of Kindergarten  Early Childhood Education
# 2135  zagazig university  Faculty of Kindergarten           Child Psychology
# 2136  zagazig university  Faculty of Kindergarten           Child Psychology
# 2137  zagazig university  Faculty of Kindergarten     Curriculum Development
# 2138  zagazig university  Faculty of Kindergarten     Curriculum Development
#
# ...

# %%
df.shape
# Out:
# (2139, 13)

# %%
df.columns
# Out:
# Index(['University_uni', 'Faculty', 'Department', 'City', 'Type',
#        'Founded_Year_clean', 'University_clean', 'Stream', 'College Type',
#        'University_stream', 'Minimum Absolute Score', 'Minimum Percentage (%)',
#        'Stream_Type'],
#       dtype='object')

# %%
df.dtypes
# Out:
# University_uni             object
# Faculty                    object
# Department                 object
# City                       object
# Type                       object
# Founded_Year_clean        float64
# University_clean           object
# Stream                     object
# College Type               object
# University_stream          object
# Minimum Absolute Score    float64
# Minimum Percentage (%)    float64
# Stream_Type                object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2139 entries, 0 to 2138
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   University_uni          2139 non-null   object
#  1   Faculty                 2139 non-null   object
#  2   Department              2139 non-null   object
#  3   City                    2139 non-null   object
#  4   Type                    2139 non-null   object
#  5   Founded_Year_clean      2070 non-null   float64
#  6   University_clean        2139 non-null   object
#  7   Stream                  2139 non-null   object
#  8   College Type            2139 non-null   object
#  9   University_stream       2139 non-null   object
#  10  Minimum Absolute Score  2139 non-null   float64
#  11  Minimum Percentage (%)  2139 non-null   float64
#  12  Stream_Type             2139 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 217.4+ KB

# %%
df.describe(include = 'all').T
# Out:
#                          count unique                  top  freq        mean  \
# University_uni            2139     14     cairo university   345         NaN
# Faculty                   2139     16  Faculty of Medicine   186         NaN
# Department                2139     65              Surgery    62         NaN
# City                      2139     13                Cairo   552         NaN
# Type                      2139      1               Public  2139         NaN
# Founded_Year_clean      2070.0    NaN                  NaN   NaN      1961.4
# University_clean          2139     14     cairo university   345         NaN
# Stream                    2139      3             Literary   828         NaN
# College Type              2139     13  Medicine (Medicine)   345         NaN
# University_stream         2139     14     Cairo University   345         NaN
# Minimum Absolute Score  2139.0    NaN                  NaN   NaN  317.451613
# ...

# %%
df.isnull().sum()
# Out:
# University_uni             0
# Faculty                    0
# Department                 0
# City                       0
# Type                       0
# Founded_Year_clean        69
# University_clean           0
# Stream                     0
# College Type               0
# University_stream          0
# Minimum Absolute Score     0
# Minimum Percentage (%)     0
# Stream_Type                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Univariate Analysis

# %%
# Getting a list of numerical columns
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterating through numerical columns and create histograms
for col in numerical_cols:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=col, kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# Getting a list of categorical columns
categorical_cols = df.select_dtypes(include='object').columns.tolist()

# Iterate through categorical columns and create countplots
for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, x=col)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# We can also use value_counts for a quick look at categorical data distribution
for col in categorical_cols:
    print(f"Value counts for {col}:\n{df[col].value_counts()}\n")
# Out:
# Value counts for University_uni:
# University_uni
# cairo university           345
# helwan university          345
# alexandria university      207
# ain shams university       207
# mansoura university        207
# beni-suef university       138
# tanta university           138
# zagazig university         138
# damietta university         69
# assiut university           69
# minia university            69
# fayoum university           69
# suez canal university       69
# south valley university     69
# Name: count, dtype: int64
#
# Value counts for Faculty:
# Faculty
# Faculty of Medicine                     186
# Faculty of Science                      186
# Faculty of Engineering                  155
# Faculty of Agriculture                  155
# Faculty of Arts                         155
# Faculty of Veterinary Medicine          155
# Faculty of Law                          124
# Faculty of Commerce                     124
# Faculty of Pharmacy                     124
# ...

# %% [markdown]
# # Bivariate Analysis

# %%
# Numerical-Numerical relationships (Scatter plots)
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through pairs of numerical columns and create scatter plots
for i in range(len(numerical_cols)):
    for j in range(i + 1, len(numerical_cols)):
        col1 = numerical_cols[i]
        col2 = numerical_cols[j]
        plt.figure(figsize=(10, 6))
        sns.scatterplot(data=df, x=col1, y=col2)
        plt.title(f'Scatter plot of {col1} vs {col2}')
        plt.xlabel(col1)
        plt.ylabel(col2)
        plt.show()

# Categorical-Numerical relationships (Box plots)
categorical_cols = df.select_dtypes(include='object').columns.tolist()
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through categorical and numerical columns and create box plots
for cat_col in categorical_cols:
    for num_col in numerical_cols:
        plt.figure(figsize=(10, 6))
        sns.boxplot(data=df, x=cat_col, y=num_col)
        plt.title(f'Box plot of {num_col} by {cat_col}')
        plt.xlabel(cat_col)
        plt.ylabel(num_col)
        plt.xticks(rotation=45, ha='right')
        plt.tight_layout()
        plt.show()

# %%
sns.pairplot(df.select_dtypes(include=np.number))
plt.suptitle('Pairplot of Numerical Features', y=1.02)
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(df.corr(numeric_only = True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix", fontsize=14)
plt.show()

# %% [markdown]
# # Thank You
