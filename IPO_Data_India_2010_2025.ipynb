# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/IPO_Data_India_2010_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
# Installing Kaggle API
# !pip install -q kaggle

# Uploading kaggle.json
from google.colab import files
files.upload()

# Moving kaggle.json to ~/.kaggle/
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# Downloading the dataset using Kaggle API
# !kaggle datasets download -d karanammithul/ipo-data-india-2010-2025

# Unziping the downloaded file
# !unzip ipo-data-india-2010-2025.zip
# Out:
#      <input type="file" id="files-b0805e0e-2c9b-4b4d-9cd9-982d619ba077" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b0805e0e-2c9b-4b4d-9cd9-982d619ba077">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel('Initial Public Offering.xlsx')
df.head(11)
# Out:
#          Date                                   IPO_Name  Issue_Size(crores)  \
# 0  2025-08-06                      M & B Engineering Ltd              650.00
# 1  2025-08-06          Sri Lotus Developers & Realty Ltd              792.00
# 2  2025-08-06  National Securities Depository Ltd (NSDL)             4011.60
# 3  2025-08-05                        Aditya Infotech Ltd             1300.00
# 4  2025-08-05                    Laxmi India Finance Ltd              254.26
# 5  2025-08-01              Shanti Gold International Ltd              360.11
# 6  2025-07-31             Brigade Hotel Ventures Limited              759.60
# 7  2025-07-30                    GNG Electronics Limited              460.44
# 8  2025-07-30                    Indiqube Spaces Limited              700.00
# 9  2025-07-21                 Anthem Biosciences Limited             3395.00
# 10 2025-07-17               Smartworks Coworking Limited              582.56
#
# ...

# %%
df.tail(11)
# Out:
#           Date                             IPO_Name  Issue_Size(crores)  \
# 550 2010-02-19        Thangamayil Jewellery Limited               28.75
# 551 2010-02-15            Syncom Healthcare Limited               56.25
# 552 2010-02-15             Vascon Engineers Limited              178.20
# 553 2010-02-23               Aqua Logistics Limited              150.00
# 554 2010-02-08           Jubilant Foodworks Limited              328.72
# 555 2010-01-29         Birla Shloka Edutech Limited               34.78
# 556 2010-02-03  Infinite Computer Solutions Limited              189.80
# 557 2010-01-06                     D B Corp Limited              384.22
# 558 2010-01-05            Godrej Properties Limited              468.85
# 559 2010-01-04                   JSW Energy Limited             2700.00
# 560 2010-01-11           MBL Infrastructure Limited              102.60
#
#        QIB     HNI    RII  Total  Offer Price  List Price  Listing Gain  ...  \
# ...

# %%
df.shape
# Out:
# (561, 21)

# %%
df.columns
# Out:
# Index(['Date', 'IPO_Name', 'Issue_Size(crores)', 'QIB', 'HNI', 'RII', 'Total',
#        'Offer Price', 'List Price', 'Listing Gain', 'CMP(BSE)', 'CMP(NSE)',
#        'Current Gains', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date                  datetime64[ns]
# IPO_Name                      object
# Issue_Size(crores)           float64
# QIB                          float64
# HNI                          float64
# RII                          float64
# Total                        float64
# Offer Price                    int64
# List Price                   float64
# Listing Gain                 float64
# CMP(BSE)                     float64
# CMP(NSE)                     float64
# Current Gains                float64
# Unnamed: 13                  float64
# Unnamed: 14                  float64
# Unnamed: 15                  float64
# Unnamed: 16                  float64
# Unnamed: 17                  float64
# Unnamed: 18                  float64
# Unnamed: 19                  float64
# Unnamed: 20                  float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                561 non-null    datetime64[ns]
#  1   IPO_Name            561 non-null    object
#  2   Issue_Size(crores)  561 non-null    float64
#  3   QIB                 559 non-null    float64
#  4   HNI                 559 non-null    float64
#  5   RII                 559 non-null    float64
#  6   Total               559 non-null    float64
#  7   Offer Price         561 non-null    int64
#  8   List Price          561 non-null    float64
#  9   Listing Gain        561 non-null    float64
#  10  CMP(BSE)            559 non-null    float64
#  11  CMP(NSE)            551 non-null    float64
#  12  Current Gains       558 non-null    float64
#  13  Unnamed: 13         0 non-null      float64
#  14  Unnamed: 14         0 non-null      float64
# ...

# %% [markdown]
# # Dropping columns that contain 'Unnamed' in their names

# %%
df = df.loc[:, ~df.columns.str.contains('Unnamed')]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                561 non-null    datetime64[ns]
#  1   IPO_Name            561 non-null    object
#  2   Issue_Size(crores)  561 non-null    float64
#  3   QIB                 559 non-null    float64
#  4   HNI                 559 non-null    float64
#  5   RII                 559 non-null    float64
#  6   Total               559 non-null    float64
#  7   Offer Price         561 non-null    int64
#  8   List Price          561 non-null    float64
#  9   Listing Gain        561 non-null    float64
#  10  CMP(BSE)            559 non-null    float64
#  11  CMP(NSE)            551 non-null    float64
#  12  Current Gains       558 non-null    float64
# dtypes: datetime64[ns](1), float64(10), int64(1), object(1)
# memory usage: 57.1+ KB

# %% [markdown]
# # Handling Outliers

# %%
Q1 = df['Offer Price'].quantile(0.25)
Q3 = df['Offer Price'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_outliers = df[(df['Offer Price'] >= lower_bound) & (df['Offer Price'] <= upper_bound)].copy()

print('Before removing outliers:', len(df))
print('After removing outleirs:', len(df_outliers))
# Out:
# Before removing outliers: 561
# After removing outleirs: 538

# %%
# Creating a figure with two subplots (1 row, 2 columns)
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

sns.boxplot(data=df, y='Offer Price', ax=axes[0])
axes[0].set_title('Box plot Before Outlier Removal')
axes[0].set_ylabel('Offer Price')

sns.boxplot(data=df_outliers, y='Offer Price', ax=axes[1])
axes[1].set_title('Box plot After Outlier Removal')
axes[1].set_ylabel('Offer Price')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Univariate Analysis

# %%
# Getting a list of numerical columns
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through numerical columns and create histograms
for col in numerical_cols:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=col, kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# Getting a list of categorical columns
categorical_cols = df.select_dtypes(include='object').columns.tolist()

# Iterate through categorical columns and create countplots
for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, x=col)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# We can also use value_counts for a quick look at categorical data distribution
for col in categorical_cols:
    print(f"Value counts for {col}:\n{df[col].value_counts()}\n")
# Out:
# Value counts for IPO_Name:
# IPO_Name
# Power Grid Corporation of India Ltd    2
# Central Depository Services Ltd        1
# ERIS Lifesciences Ltd                  1
# Tejas Networks Ltd                     1
# PSP Projects Ltd                       1
#                                       ..
# Keystone Realtors Limited              1
# Inox Green Energy Limited              1
# Kaynes Technology India Limited        1
# Archean Chemical Industries Limited    1
# Landmark Cars Limited                  1
# Name: count, Length: 560, dtype: int64

# %% [markdown]
# # Bivariate Analysis

# %%
# Numerical-Numerical relationships (Scatter plots)
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through pairs of numerical columns and create scatter plots
for i in range(len(numerical_cols)):
    for j in range(i + 1, len(numerical_cols)):
        col1 = numerical_cols[i]
        col2 = numerical_cols[j]
        plt.figure(figsize=(10, 6))
        sns.scatterplot(data=df, x=col1, y=col2)
        plt.title(f'Scatter plot of {col1} vs {col2}')
        plt.xlabel(col1)
        plt.ylabel(col2)
        plt.show()

# %%
sns.pairplot(df.select_dtypes(include=np.number))
plt.suptitle('Pairplot of Numerical Features', y=1.02)
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(df.corr(numeric_only = True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix", fontsize=14)
plt.show()

# %% [markdown]
# # Thank you
