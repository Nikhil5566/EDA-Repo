# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/Hugging_face_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
df = pd.read_csv("hf://datasets/fka/awesome-chatgpt-prompts/prompts.csv")
df.head(11)
# Out:
#                                     act  \
# 0                 An Ethereum Developer
# 1                            SEO Prompt
# 2                        Linux Terminal
# 3       English Translator and Improver
# 4                `position` Interviewer
# 5                    JavaScript Console
# 6                           Excel Sheet
# 7          English Pronunciation Helper
# 8   Spoken English Teacher and Improver
# 9                          Travel Guide
# 10                   Plagiarism Checker
#
#                                                prompt
# 0   Imagine you are an experienced Ethereum develo...
# 1   Using WebPilot, create an outline for an artic...
# 2   I want you to act as a linux terminal. I will ...
# 3   I want you to act as an English translator, sp...
# 4   I want you to act as an interviewer. I will be...
# 5   I want you to act as a javascript console. I w...
# 6   I want you to act as a text based excel. you'l...
# ...

# %%
df.tail(11)
# Out:
#                                  act  \
# 192  Architect Guide for Programmers
# 193         ChatGPT prompt generator
# 194          Children's Book Creator
# 195         Tech-Challenged Customer
# 196     Creative Branding Strategist
# 197                  Book Summarizer
# 198                    study planner
# 199                   SEO specialist
# 200            Note-Taking Assistant
# 201                     Nutritionist
# 202                 Yes or No answer
#
#                                                 prompt
# 192  You are the "Architect Guide," specialized in ...
# 193  Let's refine the process of creating high-qual...
# 194  I want you to act as a Children's Book Creator...
# 195  Pretend to be a non-tech-savvy customer callin...
# 196  You are a creative branding strategist, specia...
# 197  I want you to act as a book summarizer. Provid...
# 198  I want you to act as an advanced study plan ge...
# 199  Contributed by [@suhailroushan13](https://gith...
# ...

# %%
df.shape
# Out:
# (203, 2)

# %%
df.columns
# Out:
# Index(['act', 'prompt'], dtype='object')

# %%
df.dtypes
# Out:
# act       object
# prompt    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   act     203 non-null    object
#  1   prompt  203 non-null    object
# dtypes: object(2)
# memory usage: 3.3+ KB

# %%
df.describe(include = 'all')
# Out:
#                act                                             prompt
# count          203                                                203
# unique         201                                                203
# top     Life Coach  Imagine you are an experienced Ethereum develo...
# freq             2                                                  1

# %%
df.isnull().sum()
# Out:
# act       0
# prompt    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
