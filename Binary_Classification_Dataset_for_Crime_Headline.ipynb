# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/Binary_Classification_Dataset_for_Crime_Headline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('CrimeVsNoCrimeArticles.csv')
df.head(11)
# Out:
#                                                 title  is_crime_report
# 0          What's New and Cool in the Fitness Sphere?                0
# 1   'Today I Die,' Says Gang Leader Who Killed Sel...                1
# 2   Zero Jail Time For Cop Who Assaulted Disabled ...                1
# 3                        Three Easy Gratitude Lessons                0
# 4      Can Change At UVA Make Campuses A Safer Place?                0
# 5                        A No Bullsh-t Holiday Letter                0
# 6   Cody Tanke, Man Who Lied About Kidnapping, Now...                1
# 7   'Django Unchained': Katt Williams Threatens To...                0
# 8   Los Angeles Party Shooting Kills 3, Wounds A D...                1
# 9                           OPIC is No Model Investor                0
# 10  Missouri Executes Man Convicted Of Strangling ...                1

# %%
df.tail(11)
# Out:
#                                                   title  is_crime_report
# 7113  Albuquerque International Balloon Fiesta Start...                0
# 7114  Flooding Google: Google's New Headquarters and...                0
# 7115  Idaho Police Department Thanks 'Heroic' Nurse ...                1
# 7116  Germany's About To Bail Out Its Biggest Bank. ...                0
# 7117  The Oldest Company Logos In America: 24/7 Wall...                0
# 7118       2 Skiers Missing After Avalanche In Colorado                1
# 7119    Richard Branson: Interview With ORIGIN Magazine                0
# 7120   Clinton and Trump: Sadly, It's Politics as Usual                0
# 7121  Here's How Taylor Swift's Squad Wished Her A H...                0
# 7122  Ben Sasse Reacts To Trump's 'Horseface' Commen...                0
# 7123  Woman Faked Being Pregnant Before Kidnapping B...                1

# %%
df.shape
# Out:
# (7124, 2)

# %%
df.columns
# Out:
# Index(['title', 'is_crime_report'], dtype='object')

# %%
df.dtypes
# Out:
# title              object
# is_crime_report     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7124 entries, 0 to 7123
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            7123 non-null   object
#  1   is_crime_report  7124 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 111.4+ KB

# %%
df.describe(include = 'all')
# Out:
#                                                  title  is_crime_report
# count                                             7123      7124.000000
# unique                                            7116              NaN
# top     Dallas Shooting Suspect Confirmed Dead: Police              NaN
# freq                                                 2              NaN
# mean                                               NaN         0.500000
# std                                                NaN         0.500035
# min                                                NaN         0.000000
# 25%                                                NaN         0.000000
# 50%                                                NaN         0.500000
# 75%                                                NaN         1.000000
# max                                                NaN         1.000000

# %%
df.isnull().sum()
# Out:
# title              1
# is_crime_report    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(7)

# %% [markdown]
# # Univariate Analysis

# %%
# Getting a list of numerical columns
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through numerical columns and create histograms
for col in numerical_cols:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=col, kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# Getting a list of categorical columns
categorical_cols = df.select_dtypes(include='object').columns.tolist()

# Iterate through categorical columns and create countplots
for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, x=col)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# We can also use value_counts for a quick look at categorical data distribution
for col in categorical_cols:
    print(f"Value counts for {col}:\n{df[col].value_counts()}\n")
# Out:
# Value counts for title:
# title
# Dallas Shooting Suspect Confirmed Dead: Police                                2
# Ferguson Police Officer Shot                                                  2
# 9 Terrifying American Murder Houses                                           2
# The 20 Funniest Tweets From Women This Week                                   2
# Sunday Roundup                                                                2
#                                                                              ..
# Rodney Denk Charged With 1989 Murder Of 16-Year-Old Amy Weidner (VIDEO)       1
# Flipping the Cameras on Ourselves at StyleLikeU                               1
# Grandparenting Step-Grandchildren                                             1
# Man Charged With Hate Crimes For Allegedly Beating Women And Yanking Hijab    1
# MAG: Amazon Must Be Stopped                                                   1
# Name: count, Length: 7116, dtype: int64

# %% [markdown]
# # Bivariate Analysis

# %%
sns.pairplot(df.select_dtypes(include=np.number))
plt.suptitle('Pairplot of Numerical Features', y=1.02)
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(df.corr(numeric_only = True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix", fontsize=14)
plt.show()

# %% [markdown]
# # Thank you
