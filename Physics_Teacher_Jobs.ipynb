# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/Physics_Teacher_Jobs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('physics_teacher_jobs_linkedin.csv')
df.head(11)
# Out:
#                                                 title  \
# 0      Physics Teacher @ Roseville Pathways (2025-26)
# 1                   Upper School Physics/Math Teacher
# 2                           SCIENCE (PHYSICS) TEACHER
# 3                          Math & Science Instructors
# 4                                     Physics Teacher
# 5                       Math Instructor (Grades K-12)
# 6   Math or Science Teacher (External Applicants O...
# 7                         High School Physics Teacher
# 8                          Physics Adjunct Instructor
# 9            Science Teacher, Middle School (2025-26)
# 10  Science Teacher, High School - $10k 2025/26 Si...
#
#                      location publishedAt  \
# 0               Roseville, CA  2025-06-05
# 1               Bryn Mawr, PA  2025-05-12
# 2                   Miami, FL  2024-07-11
# 3   California, United States  2025-02-24
# 4                 Reading, PA  2023-10-03
# 5                 Oakdale, NY  2024-10-31
# ...

# %%
df.tail(11)
# Out:
#                                                  title          location  \
# 836        [2025-2026] Science Teacher - Middle School       Jamaica, NY
# 837  Science Teacher - 2024/2025 School Year (Woodl...       Chicago, IL
# 838  Middle Level Math Teacher (2025-2026 School Year)     Greenwood, SC
# 839  KIPP - Science Teacher - Middle School - San J...      San Jose, CA
# 840                   Jr. High Biology/Science Teacher  South Jordan, UT
# 841  High School History and Political Science Tuto...   Diamond Bar, CA
# 842                                    Science Teacher    Minnetonka, MN
# 843                     ELL/Bi-Lingual Science Teacher      Oak Lawn, IL
# 844          Anticipated Middle School Science Teacher  Elmwood Park, NJ
# 845               High School Physical Science Teacher      Tecumseh, OK
# 846               Adjunct Instructor - Physics (65663)  New Rochelle, NY
#
#     publishedAt                                      companyName  \
# ...

# %%
df.shape
# Out:
# (847, 11)

# %%
df.columns
# Out:
# Index(['title', 'location', 'publishedAt', 'companyName', 'description',
#        'applicationsCount', 'contractType', 'experienceLevel', 'workType',
#        'sector', 'salary'],
#       dtype='object')

# %%
df.dtypes
# Out:
# title                object
# location             object
# publishedAt          object
# companyName          object
# description          object
# applicationsCount    object
# contractType         object
# experienceLevel      object
# workType             object
# sector               object
# salary               object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 847 entries, 0 to 846
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              847 non-null    object
#  1   location           847 non-null    object
#  2   publishedAt        847 non-null    object
#  3   companyName        844 non-null    object
#  4   description        847 non-null    object
#  5   applicationsCount  847 non-null    object
#  6   contractType       847 non-null    object
#  7   experienceLevel    847 non-null    object
#  8   workType           846 non-null    object
#  9   sector             843 non-null    object
#  10  salary             153 non-null    object
# dtypes: object(11)
# memory usage: 72.9+ KB

# %%
df.isnull().sum()
# Out:
# title                  0
# location               0
# publishedAt            0
# companyName            3
# description            0
# applicationsCount      0
# contractType           0
# experienceLevel        0
# workType               1
# sector                 4
# salary               694
# dtype: int64

# %%
df.describe(include = 'all')
# Out:
#                   title      location publishedAt  \
# count               847           847         847
# unique              640           478         204
# top     Science Teacher  New York, NY  2025-06-11
# freq                 56            16          26
#
#                             companyName  \
# count                               844
# unique                              490
# top     Jefferson County Public Schools
# freq                                 19
#
#                                               description  \
# count                                                 847
# unique                                                776
# top     Primary Purpose\n\nProvide students with appro...
# freq                                                    7
#
#                        applicationsCount contractType experienceLevel  \
# count                                847          847             847
# ...

# %% [markdown]
# # Handling Outliers

# %%
df['description'] = pd.to_numeric(df['description'], errors='coerce')

Q1 = df['description'].quantile(0.25)
Q3 = df['description'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_outliers = df[(df['description'] >= lower_bound) & (df['description'] <= upper_bound)].copy()

print('Before removing Outliers:',len(df))
print('After revoming Outliers:',len(df_outliers))
# Out:
# Before removing Outliers: 847
# After revoming Outliers: 0

# %% [markdown]
# # Univariate Analysis

# %%
# Get a list of numerical columns
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through numerical columns and create histograms
for col in numerical_cols:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=col, kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# Getting a list of categorical columns
categorical_cols = df.select_dtypes(include='object').columns.tolist()

# Iterate through categorical columns and creating countplots
for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, x=col)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# We also use value_counts for a quick look at categorical data distribution
for col in categorical_cols:
    print(f"Value counts for {col}:\n{df[col].value_counts()}\n")
# Out:
# Value counts for title:
# title
# Science Teacher                                               56
# High School Science Teacher                                   20
# Middle School Science Teacher                                 15
# Math and Science Teacher                                      14
# Physics Teacher                                               12
#                                                               ..
# High School Biology Teacher                                    1
# Long-Term Substitute Physics Teacher                           1
# Upper School Science Teacher - Biology                         1
# Science Teacher - Signing Bonus Eligible                       1
# 2025-2026 SCHOOL YEAR - TEACHER (GRADE 7 SCIENCE, 1.0 FTE)     1
# Name: count, Length: 640, dtype: int64
#
# Value counts for location:
# location
# New York, NY        16
# Houston, TX         14
# Chicago, IL         13
# Louisville, KY      12
# Alvin, TX           11
# ...

# %% [markdown]
# # Thank you
