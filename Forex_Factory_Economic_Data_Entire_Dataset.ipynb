# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/Forex_Factory_Economic_Data_Entire_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('scrape.csv')
df.head(11)
# Out:
#        id             datetime currency                 event  \
# 0   12245  2007-01-01 00:00:00      CAD          Bank Holiday
# 1   12036  2007-01-01 00:00:00      CHF          Bank Holiday
# 2   23272  2007-01-01 00:00:00      CNY          Bank Holiday
# 3   12214  2007-01-01 00:00:00      EUR   French Bank Holiday
# 4   12186  2007-01-01 00:00:00      EUR   German Bank Holiday
# 5   12217  2007-01-01 00:00:00      EUR  Italian Bank Holiday
# 6   12031  2007-01-01 00:00:00      GBP          Bank Holiday
# 7   42120  2007-01-01 00:00:00      JPY          Bank Holiday
# 8   12092  2007-01-01 00:00:00      NZD          Bank Holiday
# 9   12004  2007-01-01 00:00:00      USD          Bank Holiday
# 10  18367  2007-01-01 01:00:00      CNY     Manufacturing PMI
#
#                   impact  actual actual_unit  forecast forecast_unit  \
# 0           Non-Economic     NaN         NaN       NaN           NaN
# 1           Non-Economic     NaN         NaN       NaN           NaN
# 2           Non-Economic     NaN         NaN       NaN           NaN
# 3           Non-Economic     NaN         NaN       NaN           NaN
# 4           Non-Economic     NaN         NaN       NaN           NaN
# 5           Non-Economic     NaN         NaN       NaN           NaN
# 6           Non-Economic     NaN         NaN       NaN           NaN
# 7           Non-Economic     NaN         NaN       NaN           NaN
# 8           Non-Economic     NaN         NaN       NaN           NaN
# 9           Non-Economic     NaN         NaN       NaN           NaN
# 10  High Impact Expected    54.8   unit_none       NaN           NaN
#
#     previous previous_unit previous_revised
# 0        NaN           NaN              NaN
# 1        NaN           NaN              NaN
# 2        NaN           NaN              NaN
# 3        NaN           NaN              NaN
# 4        NaN           NaN              NaN
# 5        NaN           NaN              NaN
# 6        NaN           NaN              NaN
# 7        NaN           NaN              NaN
# 8        NaN           NaN              NaN
# 9        NaN           NaN              NaN
# 10      55.3     unit_none            False

# %%
df.tail(11)
# Out:
#            id             datetime currency                             event  \
# 81758  137616  2024-12-26 16:00:00      USD             Crude Oil Inventories
# 81759  139669  2024-12-26 23:30:00      JPY                Tokyo Core CPI y/y
# 81760  139566  2024-12-26 23:30:00      JPY                 Unemployment Rate
# 81761  139542  2024-12-27 05:00:00      JPY               Consumer Confidence
# 81762  135038  2024-12-27 07:30:00      CHF                  Retail Sales y/y
# 81763  134816  2024-12-27 07:45:00      EUR      French Consumer Spending m/m
# 81764  134852  2024-12-27 07:45:00      EUR             French Prelim CPI m/m
# 81765  135050  2024-12-27 08:00:00      CHF            KOF Economic Barometer
# 81766  136938  2024-12-27 13:30:00      USD               Goods Trade Balance
# 81767  136926  2024-12-27 13:30:00      USD  Prelim Wholesale Inventories m/m
# 81768  135971  2024-12-27 15:30:00      USD               Natural Gas Storage
#
#                        impact  actual actual_unit  forecast forecast_unit  \
# 81758     Low Impact Expected     NaN         NaN       NaN           NaN
# 81759  Medium Impact Expected     NaN         NaN       NaN           NaN
# 81760     Low Impact Expected     NaN         NaN       NaN           NaN
# 81761     Low Impact Expected     NaN         NaN       NaN           NaN
# 81762     Low Impact Expected     NaN         NaN       NaN           NaN
# 81763     Low Impact Expected     NaN         NaN       NaN           NaN
# 81764     Low Impact Expected     NaN         NaN       NaN           NaN
# 81765     Low Impact Expected     NaN         NaN       NaN           NaN
# 81766     Low Impact Expected     NaN         NaN       NaN           NaN
# 81767     Low Impact Expected     NaN         NaN       NaN           NaN
# 81768     Low Impact Expected     NaN         NaN       NaN           NaN
#
#        previous previous_unit previous_revised
# 81758       NaN           NaN              NaN
# 81759       NaN           NaN              NaN
# 81760       NaN           NaN              NaN
# 81761       NaN           NaN              NaN
# 81762       NaN           NaN              NaN
# 81763       NaN           NaN              NaN
# 81764       NaN           NaN              NaN
# 81765       NaN           NaN              NaN
# 81766       NaN           NaN              NaN
# 81767       NaN           NaN              NaN
# 81768       NaN           NaN              NaN

# %%
df.shape
# Out:
# (81769, 12)

# %%
df.columns
# Out:
# Index(['id', 'datetime', 'currency', 'event', 'impact', 'actual',
#        'actual_unit', 'forecast', 'forecast_unit', 'previous', 'previous_unit',
#        'previous_revised'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                    int64
# datetime             object
# currency             object
# event                object
# impact               object
# actual              float64
# actual_unit          object
# forecast            float64
# forecast_unit        object
# previous            float64
# previous_unit        object
# previous_revised     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81769 entries, 0 to 81768
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                81769 non-null  int64
#  1   datetime          81769 non-null  object
#  2   currency          81769 non-null  object
#  3   event             81769 non-null  object
#  4   impact            81769 non-null  object
#  5   actual            62303 non-null  float64
#  6   actual_unit       64657 non-null  object
#  7   forecast          52366 non-null  float64
#  8   forecast_unit     52711 non-null  object
#  9   previous          62344 non-null  float64
#  10  previous_unit     64667 non-null  object
#  11  previous_revised  64667 non-null  object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 7.5+ MB

# %%
df.describe(include = 'all')
# Out:
#                    id             datetime currency              event  \
# count    81769.000000                81769    81769              81769
# unique            NaN                55920       10                586
# top               NaN  2016-12-22 13:30:00      USD  Unemployment Rate
# freq              NaN                   12    20914               1658
# mean     71136.756044                  NaN      NaN                NaN
# std      42512.302217                  NaN      NaN                NaN
# min       3232.000000                  NaN      NaN                NaN
# 25%      38550.000000                  NaN      NaN                NaN
# 50%      60961.000000                  NaN      NaN                NaN
# 75%     114766.000000                  NaN      NaN                NaN
# max     140436.000000                  NaN      NaN                NaN
#
#                      impact        actual      actual_unit      forecast  \
# count                 81769  62303.000000            64657  52366.000000
# unique                    4           NaN                6           NaN
# top     Low Impact Expected           NaN  unit_percentage           NaN
# freq                  38928           NaN            35980           NaN
# mean                    NaN     25.998504              NaN     25.643527
# std                     NaN    178.812442              NaN    192.140862
# min                     NaN -20537.000000              NaN -22000.000000
# 25%                     NaN      0.000000              NaN      0.200000
# 50%                     NaN      1.700000              NaN      1.500000
# 75%                     NaN     28.000000              NaN     23.400000
# max                     NaN   6648.000000              NaN   5350.000000
#
#           forecast_unit      previous    previous_unit previous_revised
# count             52711  62344.000000            64667            64667
# unique                6           NaN                6                2
# top     unit_percentage           NaN  unit_percentage            False
# freq              29719           NaN            35996            41137
# mean                NaN     25.893314              NaN              NaN
# std                 NaN    179.993984              NaN              NaN
# min                 NaN -20687.000000              NaN              NaN
# 25%                 NaN      0.000000              NaN              NaN
# 50%                 NaN      1.700000              NaN              NaN
# 75%                 NaN     28.000000              NaN              NaN
# max                 NaN   6867.000000              NaN              NaN

# %%
df.isnull().sum()
# Out:
# id                      0
# datetime                0
# currency                0
# event                   0
# impact                  0
# actual              19466
# actual_unit         17112
# forecast            29403
# forecast_unit       29058
# previous            19425
# previous_unit       17102
# previous_revised    17102
# dtype: int64

# %% [markdown]
# # Handling Missing Data:

# %%
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()
categorical_cols = df.select_dtypes(exclude=np.number).columns.tolist()


# For numerical columns, we might impute with the mean or median
for col in numerical_cols:
    if df[col].isnull().any():
        df[col].fillna(df[col].mean(), inplace=True)

# For categorical columns, we might impute with the mode or a constant
for col in categorical_cols:
    if df[col].isnull().any():
        df[col].fillna(df[col].mode()[0], inplace=True)

print("\nMissing values after handling:")
print(df.isnull().sum())
# Out:
# Missing values after handling:
# id                  0
# datetime            0
# currency            0
# event               0
# impact              0
# actual              0
# actual_unit         0
# forecast            0
# forecast_unit       0
# previous            0
# previous_unit       0
# previous_revised    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
Q1 = df['forecast'].quantile(0.25)
Q3 = df['forecast'].quantile(0.75)

IQR  = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_outliers = df[(df['forecast'] >= lower_bound) & (df['forecast'] <= upper_bound)].copy()

print('Before removing Outliers:', len(df))
print('After Removing Outliers:', len(df_outliers))
# Out:
# Before removing Outliers: 81769
# After Removing Outliers: 75993

# %%
# Creating a figure with two subplots (1 row, 2 columns)
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

sns.boxplot(data=df, y='forecast', ax=axes[0])
axes[0].set_title('Box plot Before Outlier Removal')
axes[0].set_ylabel('forecast')

sns.boxplot(data=df_outliers, y='forecast', ax=axes[1])
axes[1].set_title('Box plot After Outlier Removal')
axes[1].set_ylabel('Tforecast')

plt.tight_layout()

plt.show()

# %% [markdown]
# # Univariate Analysis

# %%
# Getting a list of numerical columns
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through numerical columns and create histograms
for col in numerical_cols:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=col, kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# Getting a list of categorical columns
categorical_cols = df.select_dtypes(include='object').columns.tolist()

# Iterate through categorical columns and create countplots
for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, x=col)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# We can also use value_counts for a quick look at categorical data distribution
for col in categorical_cols:
    print(f"Value counts for {col}:\n{df[col].value_counts()}\n")
# Out:
# Value counts for datetime:
# datetime
# 2016-12-22 13:30:00    12
# 2020-01-01 00:00:00    10
# 2020-05-07 06:00:00    10
# 2020-08-06 06:00:00    10
# 2019-01-01 00:00:00    10
#                        ..
# 2015-12-10 00:01:00     1
# 2015-12-10 00:10:00     1
# 2015-12-10 06:30:00     1
# 2009-11-02 21:45:00     1
# 2015-12-09 15:00:00     1
# Name: count, Length: 55920, dtype: int64
#
# Value counts for currency:
# currency
# USD    20914
# EUR    17398
# GBP    11029
# JPY     7845
# AUD     6707
# CAD     5927
# NZD     4364
# CNY     3819
# CHF     3101
# All      665
# Name: count, dtype: int64
#
# Value counts for event:
# event
# Unemployment Rate                      1658
# Bank Holiday                           1624
# Trade Balance                          1411
# Retail Sales m/m                       1130
# Unemployment Claims                     939
#                                        ...
# Italian Constitution Amendment Vote       1
# Greek Bailout Vote                        1
# Unconditional Basic Income Vote           1
# EU Membership Vote                        1
# Doha Oil Summit                           1
# Name: count, Length: 586, dtype: int64
#
# Value counts for impact:
# impact
# Low Impact Expected       38928
# Medium Impact Expected    22920
# High Impact Expected      17563
# Non-Economic               2358
# Name: count, dtype: int64
#
# Value counts for actual_unit:
# actual_unit
# unit_percentage    53092
# unit_none          16780
# unit_billion        5950
# unit_thousand       3261
# unit_million        2263
# unit_trillion        423
# Name: count, dtype: int64
#
# Value counts for forecast_unit:
# forecast_unit
# unit_percentage    58777
# unit_none          11790
# unit_billion        5456
# unit_thousand       3123
# unit_million        2199
# unit_trillion        424
# Name: count, dtype: int64
#
# Value counts for previous_unit:
# previous_unit
# unit_percentage    53098
# unit_none          16777
# unit_billion        5949
# unit_thousand       3256
# unit_million        2266
# unit_trillion        423
# Name: count, dtype: int64

# %% [markdown]
# # Bivariate Analysis

# %%
# Numerical-Numerical relationships (Scatter plots)
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through pairs of numerical columns and create scatter plots
for i in range(len(numerical_cols)):
    for j in range(i + 1, len(numerical_cols)):
        col1 = numerical_cols[i]
        col2 = numerical_cols[j]
        plt.figure(figsize=(10, 6))
        sns.scatterplot(data=df, x=col1, y=col2)
        plt.title(f'Scatter plot of {col1} vs {col2}')
        plt.xlabel(col1)
        plt.ylabel(col2)
        plt.show()

# Categorical-Numerical relationships (Box plots)
categorical_cols = df.select_dtypes(include='object').columns.tolist()
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through categorical and numerical columns and create box plots
for cat_col in categorical_cols:
    for num_col in numerical_cols:
        plt.figure(figsize=(10, 6))
        sns.boxplot(data=df, x=cat_col, y=num_col)
        plt.title(f'Box plot of {num_col} by {cat_col}')
        plt.xlabel(cat_col)
        plt.ylabel(num_col)
        plt.xticks(rotation=45, ha='right')
        plt.tight_layout()
        plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(df.corr(numeric_only = True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix", fontsize=14)
plt.show()

# %% [markdown]
# # Thank you
