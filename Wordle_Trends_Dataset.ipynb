# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/Wordle_Trends_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('wordle_trend_data.csv')
df.head(11)
# Out:
#           date  game   word  wordfreq_commonality  subtlex_commonality  \
# 0   2025-06-24  1466  elite                0.0005               0.1293
# 1   2025-06-23  1465  oddly                0.0001               0.1051
# 2   2025-06-22  1464  thrum                0.0000               0.0106
# 3   2025-06-21  1463  glade                0.0000               0.0309
# 4   2025-06-20  1462  taupe                0.0000               0.0493
# 5   2025-06-19  1461  curio                0.0000               0.0156
# 6   2025-06-18  1460  munch                0.0000               0.0573
# 7   2025-06-17  1459  prank                0.0001               0.1512
# 8   2025-06-16  1458  petty                0.0002               0.2124
# 9   2025-06-15  1457  quail                0.0000               0.0795
# 10  2025-06-14  1456  ghost                0.0005               0.3408
#
#     trend_day_language  trend_avg_200_language  trend_day_global  \
# 0                100.0                   19.42              75.0
# 1                100.0                    0.38             100.0
# 2                100.0                    0.04             100.0
# 3                100.0                    0.14             100.0
# 4                100.0                    0.47             100.0
# 5                100.0                    0.19             100.0
# 6                100.0                    5.64             100.0
# 7                 88.0                   24.48              25.0
# 8                100.0                   32.46              92.0
# 9                100.0                    1.50              86.0
# 10                71.0                   69.46              71.0
#
#     trend_avg_200_global
# 0                  69.08
# 1                  10.94
# 2                   0.04
# 3                  15.20
# 4                  12.39
# 5                   3.74
# 6                  57.91
# 7                  23.02
# 8                  57.94
# 9                  27.44
# 10                 68.04

# %%
df.tail(11)
# Out:
#             date  game   word  wordfreq_commonality  subtlex_commonality  \
# 1456  2021-06-29    10  heath                0.0001               0.0987
# 1457  2021-06-28     9  serve                0.0014               0.3441
# 1458  2021-06-27     8  naval                0.0003               0.1792
# 1459  2021-06-26     7  evade                0.0000               0.0593
# 1460  2021-06-25     6  focal                0.0001               0.0424
# 1461  2021-06-24     5  blush                0.0001               0.1222
# 1462  2021-06-23     4  awake                0.0003               0.3121
# 1463  2021-06-22     3  humph                0.0000               0.0296
# 1464  2021-06-21     2  sissy                0.0000               0.1987
# 1465  2021-06-20     1  rebut                0.0000               0.0139
# 1466  2021-06-19     0  cigar                0.0001               0.2476
#
#       trend_day_language  trend_avg_200_language  trend_day_global  \
# 1456                 0.0                   15.11              42.0
# 1457                63.0                   64.51              85.0
# 1458                 0.0                   14.59              69.0
# 1459                 0.0                   14.76              47.0
# 1460                 0.0                   16.07              80.0
# 1461                45.0                   35.10              75.0
# 1462                37.0                   33.70              22.0
# 1463                 0.0                    0.50               0.0
# 1464                 0.0                    5.03              73.0
# 1465                 0.0                    1.84              42.0
# 1466                 0.0                    1.80              95.0
#
#       trend_avg_200_global
# 1456                 45.36
# 1457                 85.04
# 1458                 72.36
# 1459                 53.09
# 1460                 82.70
# 1461                 75.60
# 1462                 18.06
# 1463                  9.34
# 1464                 75.94
# 1465                 53.74
# 1466                 66.10

# %%
df.shape
# Out:
# (1467, 9)

# %%
df.columns
# Out:
# Index(['date', 'game', 'word', 'wordfreq_commonality', 'subtlex_commonality',
#        'trend_day_language', 'trend_avg_200_language', 'trend_day_global',
#        'trend_avg_200_global'],
#       dtype='object')

# %%
df.dtypes
# Out:
# date                       object
# game                        int64
# word                       object
# wordfreq_commonality      float64
# subtlex_commonality       float64
# trend_day_language        float64
# trend_avg_200_language    float64
# trend_day_global          float64
# trend_avg_200_global      float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1467 entries, 0 to 1466
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    1467 non-null   object
#  1   game                    1467 non-null   int64
#  2   word                    1467 non-null   object
#  3   wordfreq_commonality    1467 non-null   float64
#  4   subtlex_commonality     1467 non-null   float64
#  5   trend_day_language      1458 non-null   float64
#  6   trend_avg_200_language  1458 non-null   float64
#  7   trend_day_global        1467 non-null   float64
#  8   trend_avg_200_global    1467 non-null   float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 103.3+ KB

# %%
df.describe(include = 'all')
# Out:
#               date         game   word  wordfreq_commonality  \
# count         1467  1467.000000   1467           1467.000000
# unique        1467          NaN   1467                   NaN
# top     2021-06-19          NaN  cigar                   NaN
# freq             1          NaN      1                   NaN
# mean           NaN   733.000000    NaN              0.000920
# std            NaN   423.630735    NaN              0.003324
# min            NaN     0.000000    NaN              0.000000
# 25%            NaN   366.500000    NaN              0.000000
# 50%            NaN   733.000000    NaN              0.000100
# 75%            NaN  1099.500000    NaN              0.000500
# max            NaN  1466.000000    NaN              0.047900
#
#         subtlex_commonality  trend_day_language  trend_avg_200_language  \
# count           1467.000000         1458.000000             1458.000000
# unique                  NaN                 NaN                     NaN
# top                     NaN                 NaN                     NaN
# freq                    NaN                 NaN                     NaN
# mean               0.180377           79.563786               26.713457
# std                0.157176           29.687142               27.061942
# min                0.000000            0.000000                0.000000
# 25%                0.052600           65.000000                1.292500
# 50%                0.136000          100.000000               16.165000
# 75%                0.275700          100.000000               51.850000
# max                0.787200          100.000000               86.220000
#
#         trend_day_global  trend_avg_200_global
# count        1467.000000           1467.000000
# unique               NaN                   NaN
# top                  NaN                   NaN
# freq                 NaN                   NaN
# mean           79.149966             44.159755
# std            24.228660             28.680264
# min             0.000000              0.020000
# 25%            65.000000             16.815000
# 50%            87.000000             45.230000
# 75%           100.000000             71.215000
# max           100.000000             92.020000

# %%
df.isnull().sum()
# Out:
# date                      0
# game                      0
# word                      0
# wordfreq_commonality      0
# subtlex_commonality       0
# trend_day_language        9
# trend_avg_200_language    9
# trend_day_global          0
# trend_avg_200_global      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
Q1 = df['game'].quantile(0.25)
Q3 = df['game'].quantile(0.75)

IQR  = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_outliers = df[(df['game'] >= lower_bound) & (df['game'] <= upper_bound)].copy()

print('Before removing Outliers:', len(df))
print('After Removing Outliers:', len(df_outliers))
# Out:
# Before removing Outliers: 1467
# After Removing Outliers: 1467

# %% [markdown]
# # Univariate Analysis

# %%
# Getting a list of numerical columns
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through numerical columns and create histograms
for col in numerical_cols:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=col, kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# Getting a list of categorical columns
categorical_cols = df.select_dtypes(include='object').columns.tolist()

# Iterate through categorical columns and create countplots
for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, x=col)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# We can also use value_counts for a quick look at categorical data distribution
for col in categorical_cols:
    print(f"Value counts for {col}:\n{df[col].value_counts()}\n")
# Out:
# Value counts for date:
# date
# 2021-06-19    1
# 2025-06-24    1
# 2025-06-23    1
# 2025-06-22    1
# 2025-06-21    1
#              ..
# 2025-06-09    1
# 2025-06-10    1
# 2025-06-11    1
# 2025-06-12    1
# 2025-06-13    1
# Name: count, Length: 1467, dtype: int64
#
# Value counts for word:
# word
# cigar    1
# elite    1
# oddly    1
# thrum    1
# glade    1
#         ..
# board    1
# taffy    1
# plaid    1
# vixen    1
# bilge    1
# Name: count, Length: 1467, dtype: int64

# %% [markdown]
# # Bivariate Analysis

# %%
# Numerical-Numerical relationships (Scatter plots)
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through pairs of numerical columns and create scatter plots
for i in range(len(numerical_cols)):
    for j in range(i + 1, len(numerical_cols)):
        col1 = numerical_cols[i]
        col2 = numerical_cols[j]
        plt.figure(figsize=(10, 6))
        sns.scatterplot(data=df, x=col1, y=col2)
        plt.title(f'Scatter plot of {col1} vs {col2}')
        plt.xlabel(col1)
        plt.ylabel(col2)
        plt.show()

# Categorical-Numerical relationships (Box plots)
categorical_cols = df.select_dtypes(include='object').columns.tolist()
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through categorical and numerical columns and create box plots
for cat_col in categorical_cols:
    for num_col in numerical_cols:
        plt.figure(figsize=(10, 6))
        sns.boxplot(data=df, x=cat_col, y=num_col)
        plt.title(f'Box plot of {num_col} by {cat_col}')
        plt.xlabel(cat_col)
        plt.ylabel(num_col)
        plt.xticks(rotation=45, ha='right')
        plt.tight_layout()
        plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(df.corr(numeric_only = True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix", fontsize=14)
plt.show()

# %% [markdown]
# # Thank you
