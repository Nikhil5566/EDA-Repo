# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/Blood_Donor_Data_Analysis_and_Prediction_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('blood_donor_dataset.csv')
df.head(11)
# Out:
#       donor_id                  name                          email  \
# 0   1b8b4c828a          Norma Fisher            ysullivan@yahoo.com
# 1   a6a3f7fe55         Eugene Bowman       hramos@brown-sellers.com
# 2   cee6478144      Sheri Bolton DDS          jasmine85@hotmail.com
# 3   5986bc55f9            Kelly Boyd  pattylawrence@riley-hayes.com
# 4   93246afe6c         Taylor Guzman       martinezjacob@wilson.com
# 5   486ffe4e4a     Jonathan Williams         wgonzalez@harrison.com
# 6   32e4e74c30         Bob Stevenson           johnbenton@yahoo.com
# 7   62927f7975         Amanda Savage        martincaleb@hotmail.com
# 8   17a47b3f43        Jennifer Smith            bairdemma@davis.com
# 9   c6f6371120          Daniel Green           sheena09@hotmail.com
# 10  f89330b850  Mrs. Jennifer Kelley            woodsjohn@gmail.com
#
#       password contact_number       city blood_group availability  \
# 0   P5hX6Syg*A  +61 461706749     Hobart          A+           No
# ...

# %%
df.tail(11)
# Out:
#         donor_id                  name                         email  \
# 9989  3ad400f8ea         Melissa Baker      comptonjeffrey@yahoo.com
# 9990  38eec7e71e         Blake Mendoza         cameron93@hotmail.com
# 9991  dbda81ddba       Connie Williams    manderson@stone-osborn.com
# 9992  b4652280e3  Rebecca Martinez DVM             aaron52@gmail.com
# 9993  5fbc80a83c            Anna Gomez        crawfordmark@marsh.org
# 9994  839e77a5ee            Tonya Cole              xjensen@gill.com
# 9995  700aeefbf1          Bradley Pham          jessica49@turner.com
# 9996  487b342992        Richard Harris             megan51@gmail.com
# 9997  ddf4485d67            Autumn Kim      curtisdonald@wilson.info
# 9998  4256813ba5         Janice Murphy  jenningscristian@hotmail.com
# 9999  5452d8afd3         Edward Graham              oyates@yahoo.com
#
#         password contact_number       city blood_group availability  \
# 9989  @7GqA0chHj  +61 446715243  Melbourne          B+          Yes
# ...

# %%
df.shape
# Out:
# (10000, 12)

# %%
df.columns
# Out:
# Index(['donor_id', 'name', 'email', 'password', 'contact_number', 'city',
#        'blood_group', 'availability', 'months_since_first_donation',
#        'number_of_donation', 'pints_donated', 'created_at'],
#       dtype='object')

# %%
df.dtypes
# Out:
# donor_id                       object
# name                           object
# email                          object
# password                       object
# contact_number                 object
# city                           object
# blood_group                    object
# availability                   object
# months_since_first_donation     int64
# number_of_donation              int64
# pints_donated                   int64
# created_at                     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   donor_id                     10000 non-null  object
#  1   name                         10000 non-null  object
#  2   email                        10000 non-null  object
#  3   password                     10000 non-null  object
#  4   contact_number               10000 non-null  object
#  5   city                         10000 non-null  object
#  6   blood_group                  10000 non-null  object
#  7   availability                 10000 non-null  object
#  8   months_since_first_donation  10000 non-null  int64
#  9   number_of_donation           10000 non-null  int64
#  10  pints_donated                10000 non-null  int64
#  11  created_at                   10000 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 937.6+ KB

# %%
df.describe(include = 'all')
# Out:
#           donor_id           name             email    password  \
# count        10000          10000             10000       10000
# unique       10000           9419              9954       10000
# top     182d443192  Robert Wilson  gsmith@yahoo.com  N8DQsBhg_K
# freq             1              8                 3           1
# mean           NaN            NaN               NaN         NaN
# std            NaN            NaN               NaN         NaN
# min            NaN            NaN               NaN         NaN
# 25%            NaN            NaN               NaN         NaN
# 50%            NaN            NaN               NaN         NaN
# 75%            NaN            NaN               NaN         NaN
# max            NaN            NaN               NaN         NaN
#
#        contact_number      city blood_group availability  \
# count           10000     10000       10000        10000
# unique           9998         8           8            2
# ...

# %%
df.isnull().sum()
# Out:
# donor_id                       0
# name                           0
# email                          0
# password                       0
# contact_number                 0
# city                           0
# blood_group                    0
# availability                   0
# months_since_first_donation    0
# number_of_donation             0
# pints_donated                  0
# created_at                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Hanlding Outliers

# %%
Q1 = df['number_of_donation'].quantile(0.25)
Q3 = df['number_of_donation'].quantile(0.75)

IQR  = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_outliers = df[(df['number_of_donation'] >= lower_bound) & (df['number_of_donation'] <= upper_bound)].copy()

print('Before removing Outliers:', len(df))
print('After Removing Outliers:', len(df_outliers))
# Out:
# Before removing Outliers: 10000
# After Removing Outliers: 10000

# %% [markdown]
# # Univariate Analysis

# %%
# Getting a list of numerical columns
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through numerical columns and create histograms
for col in numerical_cols:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=col, kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# Getting a list of categorical columns
categorical_cols = df.select_dtypes(include='object').columns.tolist()

# Exclude columns with potentially problematic characters and those not relevant for this analysis
exclude_cols = ['donor_id', 'name', 'email', 'password', 'contact_number']
categorical_cols_filtered = [col for col in categorical_cols if col not in exclude_cols]

# Iterate through filtered categorical columns and create countplots
for col in categorical_cols_filtered:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, x=col)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# We can also use value_counts for a quick look at categorical data distribution
for col in categorical_cols_filtered:
    print(f"Value counts for {col}:\n{df[col].value_counts()}\n")
# Out:
# Value counts for city:
# city
# Canberra     1283
# Sydney       1272
# Brisbane     1269
# Darwin       1254
# Adelaide     1250
# Melbourne    1241
# Hobart       1233
# Perth        1198
# Name: count, dtype: int64
#
# Value counts for blood_group:
# blood_group
# B-     1290
# AB-    1284
# B+     1282
# O+     1240
# A+     1238
# A-     1236
# AB+    1219
# O-     1211
# Name: count, dtype: int64
#
# Value counts for availability:
# availability
# Yes    5085
# No     4915
# Name: count, dtype: int64
#
# Value counts for created_at:
# created_at
# 2016-07-16    10
# 2024-12-10    10
# 2023-01-20    10
# 2020-03-20    10
# 2019-02-25     9
#               ..
# 2024-02-22     1
# 2016-09-18     1
# 2019-04-29     1
# 2019-03-11     1
# 2017-06-22     1
# Name: count, Length: 3409, dtype: int64

# %% [markdown]
# # Bivariate Analysis

# %%
# Numerical-Numerical relationships (Scatter plots)
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through pairs of numerical columns and create scatter plots
for i in range(len(numerical_cols)):
    for j in range(i + 1, len(numerical_cols)):
        col1 = numerical_cols[i]
        col2 = numerical_cols[j]
        plt.figure(figsize=(10, 6))
        sns.scatterplot(data=df, x=col1, y=col2)
        plt.title(f'Scatter plot of {col1} vs {col2}')
        plt.xlabel(col1)
        plt.ylabel(col2)
        plt.show()

# Categorical-Numerical relationships (Box plots)
categorical_cols = df.select_dtypes(include='object').columns.tolist()
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Exclude columns with potentially problematic characters and those not relevant for this analysis
exclude_cols = ['donor_id', 'name', 'email', 'password', 'contact_number']
categorical_cols_filtered = [col for col in categorical_cols if col not in exclude_cols]


# Iterate through filtered categorical and numerical columns and create box plots
for cat_col in categorical_cols_filtered:
    for num_col in numerical_cols:
        plt.figure(figsize=(10, 6))
        sns.boxplot(data=df, x=cat_col, y=num_col)
        plt.title(f'Box plot of {num_col} by {cat_col}')
        plt.xlabel(cat_col)
        plt.ylabel(num_col)
        plt.xticks(rotation=45, ha='right')
        plt.tight_layout()
        plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(df.corr(numeric_only = True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix", fontsize=14)
plt.show()

# %% [markdown]
# # Thank you
